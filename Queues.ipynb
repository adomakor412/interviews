# %%
import math
# Add any extra import statements you may need here
from collections import deque
import queue

# %%
def findPositions(arr, x):
  # Write your code here
  inArr = arr
  iters = x
  cnt = 0
  myArr = []
  n = len(arr)
  
  
  while len(myArr)<iters: 
    cnt+=1
    q = queue.Queue()
    auxQList = []
    
    for num in inArr:
      q.put(num)
    
    for i in range(iters):
      val = q.get()
      auxQList.append(val-1)
    
    inArr = inArr[iters:]
    inArr += auxQList[:iters]
    
    ext_ind = cnt * iters + inArr.index( max(inArr) )
    print(ext_ind % n)
    myArr.append( ext_ind % n )
    
  return myArr

  









# These are the tests we use to determine if the solution is correct.
# You can add your own at the bottom.

def printInteger(n):
  print('[', n, ']', sep='', end='')

def printIntegerList(array):
  size = len(array)
  print('[', end='')
  for i in range(size):
    if i != 0:
      print(', ', end='')
    print(array[i], end='')
  print(']', end='')

test_case_number = 1

def check(expected, output):
  global test_case_number
  expected_size = len(expected)
  output_size = len(output)
  result = True
  if expected_size != output_size:
    result = False
  for i in range(min(expected_size, output_size)):
    result &= (output[i] == expected[i])
  rightTick = '\u2713'
  wrongTick = '\u2717'
  if result:
    print(rightTick, 'Test #', test_case_number, sep='')
  else:
    print(wrongTick, 'Test #', test_case_number, ': Expected ', sep='', end='')
    printIntegerList(expected)
    print(' Your output: ', end='')
    printIntegerList(output)
    print()
  test_case_number += 1

if __name__ == "__main__":
  n_1 = 6
  x_1 = 5
  arr_1 = [1, 2, 2, 3, 4, 5]
  expected_1 = [5, 6, 4, 1, 2]
  output_1 = findPositions(arr_1, x_1)
  check(expected_1, output_1)

  n_2 = 13
  x_2 = 4
  arr_2 = [2, 4, 2, 4, 3, 1, 2, 2, 3, 4, 3, 4, 4]
  expected_2 = [2, 5, 10, 13]
  output_2 = findPositions(arr_2, x_2)
  check(expected_2, output_2)

  # Add your own test cases here
# Out:
# 5
# 5
# 5
# 5
# 5
# ✗Test #1: Expected [5, 6, 4, 1, 2] Your output: [5, 5, 5, 5, 5]
# 9
# 9
# 12
# 3
# ✗Test #2: Expected [2, 5, 10, 13] Your output: [9, 9, 12, 3]

# %%
#https://leetcode.com/discuss/interview-question/1039925/Facebook-Practice-question-or-Queue-Removals/944478
#https://leetcode.com/discuss/interview-question/1039925/Facebook-Practice-question-or-Queue-Removals/1000538

def getMaxIndex(cnt, aQueue, x, n):
  auxArr = []
  for i in range(x):
    #val = q.get()[0]
    val = aQueue.get()
    auxArr.append(val)
  maxVal = max(auxArr)
  outIndex = (auxArr.index(maxVal) + x*cnt - cnt)%n
  
  auxArr.remove(maxVal)
  
  return outIndex, auxArr
  

def findPositions(arr, x):
  # Write your code here
  inArr = arr
  iters = x
  cnt = 0
  myArr = []
  n = len(arr)
    
  for i in range(x):
    
    q = queue.Queue()
    
    minLen =  min(x, len(inArr))
    
    for j in range(minLen):
      q.put(inArr[j])
      
    ind, auxArr = getMaxIndex(i, q, minLen, n)
    myArr.append(ind)
    inArr = inArr[x:]+auxArr
    
  return myArr



# These are the tests we use to determine if the solution is correct.
# You can add your own at the bottom.

def printInteger(n):
  print('[', n, ']', sep='', end='')

def printIntegerList(array):
  size = len(array)
  print('[', end='')
  for i in range(size):
    if i != 0:
      print(', ', end='')
    print(array[i], end='')
  print(']', end='')

test_case_number = 1

def check(expected, output):
  global test_case_number
  expected_size = len(expected)
  output_size = len(output)
  result = True
  if expected_size != output_size:
    result = False
  for i in range(min(expected_size, output_size)):
    result &= (output[i] == expected[i])
  rightTick = '\u2713'
  wrongTick = '\u2717'
  if result:
    print(rightTick, 'Test #', test_case_number, sep='')
  else:
    print(wrongTick, 'Test #', test_case_number, ': Expected ', sep='', end='')
    printIntegerList(expected)
    print(' Your output: ', end='')
    printIntegerList(output)
    print()
  test_case_number += 1

if __name__ == "__main__":
  n_1 = 6
  x_1 = 5
  arr_1 = [1, 2, 2, 3, 4, 5]
  expected_1 = [5, 6, 4, 1, 2]
  output_1 = findPositions(arr_1, x_1)
  check(expected_1, output_1)

  n_2 = 13
  x_2 = 4
  arr_2 = [2, 4, 2, 4, 3, 1, 2, 2, 3, 4, 3, 4, 4]
  expected_2 = [2, 5, 10, 13]
  output_2 = findPositions(arr_2, x_2)
  check(expected_2, output_2)

  # Add your own test cases here
# Out:
# ✗Test #1: Expected [5, 6, 4, 1, 2] Your output: [4, 4, 3, 1, 5]
# ✗Test #2: Expected [2, 5, 10, 13] Your output: [1, 3, 7, 9]

# %%
# Add any helper functions you may need here

def findPositions(arr, x):
  # Write your code here
    d = deque( [(n, i) for i, n in enumerate(arr, start=1)] )
    ret = []
    for _ in range(x):
        mx = float('-inf')
        q = queue.Queue()
    
        j = 0
        ind = None
        while len(d)>0 and j<x:
            #print(d)
            n, i = d.popleft()
            if n > mx:
                mx, mxj, mxi = n, j, i
                ind = mxi
            q.put( (max(0,n-1), i) )
            j+=1
        
        
        while not q.empty():
            #print(q.get())
            
            #print(q)
            vals = q.get()
            #print(vals)
            if (vals[1] != ind):
            #if vals[1] != max(0,mx-1):
                #print(vals)
                d.append(vals)
            
        ret.append(mxi)
    return ret

# These are the tests we use to determine if the solution is correct.
# You can add your own at the bottom.

def printInteger(n):
  print('[', n, ']', sep='', end='')

def printIntegerList(array):
  size = len(array)
  print('[', end='')
  for i in range(size):
    if i != 0:
      print(', ', end='')
    print(array[i], end='')
  print(']', end='')

test_case_number = 1

def check(expected, output):
  global test_case_number
  expected_size = len(expected)
  output_size = len(output)
  result = True
  if expected_size != output_size:
    result = False
  for i in range(min(expected_size, output_size)):
    result &= (output[i] == expected[i])
  rightTick = '\u2713'
  wrongTick = '\u2717'
  if result:
    print(rightTick, 'Test #', test_case_number, sep='')
  else:
    print(wrongTick, 'Test #', test_case_number, ': Expected ', sep='', end='')
    printIntegerList(expected)
    print(' Your output: ', end='')
    printIntegerList(output)
    print()
  test_case_number += 1

if __name__ == "__main__":
  n_1 = 6
  x_1 = 5
  arr_1 = [1, 2, 2, 3, 4, 5]
  expected_1 = [5, 6, 4, 1, 2]
  output_1 = findPositions(arr_1, x_1)
  check(expected_1, output_1)

  n_2 = 13
  x_2 = 4
  arr_2 = [2, 4, 2, 4, 3, 1, 2, 2, 3, 4, 3, 4, 4]
  expected_2 = [2, 5, 10, 13]
  output_2 = findPositions(arr_2, x_2)
  check(expected_2, output_2)

  # Add your own test cases here
# Out:
# ✓Test #1
# ✓Test #2

# %%
def findPositions(arr, x):
  # Write your code here
  q = deque([(n,i+1) for i,n in enumerate(arr)])
  ret = []
  
  for _ in range(x):
    mx = float('-inf')
    popped = []
    
    j = 0
    while q and j < x:
      n,i = q.popleft()
      if n > mx:
        mx = n
        mxj = j
        mxi = i
      popped.append((max(0, n-1), i))
      j += 1
      
      
    if popped:
      popped.pop(mxj)
    if popped:
      q.extend(popped)
    
    ret.append(mxi)
    
  return ret


def printInteger(n):
  print('[', n, ']', sep='', end='')

def printIntegerList(array):
  size = len(array)
  print('[', end='')
  for i in range(size):
    if i != 0:
      print(', ', end='')
    print(array[i], end='')
  print(']', end='')

test_case_number = 1

def check(expected, output):
  global test_case_number
  expected_size = len(expected)
  output_size = len(output)
  result = True
  if expected_size != output_size:
    result = False
  for i in range(min(expected_size, output_size)):
    result &= (output[i] == expected[i])
  rightTick = '\u2713'
  wrongTick = '\u2717'
  if result:
    print(rightTick, 'Test #', test_case_number, sep='')
  else:
    print(wrongTick, 'Test #', test_case_number, ': Expected ', sep='', end='')
    printIntegerList(expected)
    print(' Your output: ', end='')
    printIntegerList(output)
    print()
  test_case_number += 1

if __name__ == "__main__":
  n_1 = 6
  x_1 = 5
  arr_1 = [1, 2, 2, 3, 4, 5]
  expected_1 = [5, 6, 4, 1, 2]
  output_1 = findPositions(arr_1, x_1)
  check(expected_1, output_1)

  n_2 = 13
  x_2 = 4
  arr_2 = [2, 4, 2, 4, 3, 1, 2, 2, 3, 4, 3, 4, 4]
  expected_2 = [2, 5, 10, 13]
  output_2 = findPositions(arr_2, x_2)
  check(expected_2, output_2)
# Out:
# ✓Test #1
# ✓Test #2
